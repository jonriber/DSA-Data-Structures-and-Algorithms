# %% [markdown]
# # Short coding sessions
#
# Today's topic is : `Truthness, falsiness and sentinel objects`
#
# ## Step 1 - predict before running
#
# ```python
#     values = [None, 0, "".[]. {}, False, 0.0]
#
#     for v in values:
#         print(v, bool(v))
# ```
#
# ## Step 2 - Observations
#
# I have a function with a subtle bug:
#
# ```python
#     def process(value=None):
#         if not value:
#             return "DEFAULT"
#         return value
# ```
#
# the above function is lying.
#
# The task:
#
# 1. Explain what the bug is
# 2. Fix it so that:
#     - None --> "DEFAULT"
#     - 0, "", [], Flase --> returned as-is
# 3. Do not break existing behavior
# 4. Do not add unnecessary conditionals
#
# ## Step 3 - Contraints
#
# - Must use a `sentinel object`
#
# ## Step 4 - Learnings
#
# - Python's truthiness rules
# - Why `if not value` is often wrong
# - How sentinel objects create honest APIs
# - The difference between "missing" and "empty"
