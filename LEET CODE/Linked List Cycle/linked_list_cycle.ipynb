# %% [markdown]
# # Linked List Cycle - LeetCode
#
# Link: <https://leetcode.com/problems/linked-list-cycle/description>
#
# ## Description
#
# Given `head`, the head of a linked list, determine if the linked list has a `cycle` in it.
#
# There is a cycle in a linked list if there is some `node` in the list that can be reached `again` by continuously following the `next` pointer. Internally,
# `pos` is used to denote the index of the node that tail's next pointer is `connected` to. Note that pos is not passed as a parameter.
#
# ## Examples
#
# ![image.png](attachment:image.png)
#
# Input: head = [3,2,0,-4], pos = 1
# Output: true
# Explanation: There is a cycle in the linked list, where the tail connects to the 1st node (0-indexed).
#
# ## Solution
#
# ### Approach 1
#
# HashSet --> It is easy to implement but it consumes O(n) space
#
# O(n) is linear big O notation, which means time grows as input increases.

# %%
# Approach number 1

class Solution():
    def hasCycle(self, head):
        visited = set()
        current = head

        while current:
            if current in visited:
                return True
            visited.add(current)
            current = current.next
        return False
